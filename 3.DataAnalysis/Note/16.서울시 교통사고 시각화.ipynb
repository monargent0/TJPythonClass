# %% [markdown]
# # 서울시 교통사고 시각화

# %%
import pandas as pd

# %%
traffic_Seoul = pd.read_csv('../Data/newSeoul_2005_2019.csv', encoding='utf-8')
traffic_Seoul.head()
# Out:
#      년도  월 자치구명  발생건수  사망자수  부상자수
# 0  2005  1  종로구    93     2   138
# 1  2005  2  종로구    84     3   125
# 2  2005  3  종로구   117     0   142
# 3  2005  4  종로구   138     2   212
# 4  2005  5  종로구   145     2   207

# %%
traffic_Seoul_2019 = traffic_Seoul[traffic_Seoul['년도'] == 2019]
traffic_Seoul_2019.head()
# Out:
#         년도  월 자치구명  발생건수  사망자수  부상자수
# 4200  2019  1  종로구    87     1   125
# 4201  2019  2  종로구    66     1    84
# 4202  2019  3  종로구    87     2   122
# 4203  2019  4  종로구    85     0   131
# 4204  2019  5  종로구   112     1   158

# %%
# index 0번부터
traffic_Seoul_2019.reset_index(drop=True, inplace=True)
traffic_Seoul_2019
# Out:
#        년도   월 자치구명  발생건수  사망자수  부상자수
# 0    2019   1  종로구    87     1   125
# 1    2019   2  종로구    66     1    84
# 2    2019   3  종로구    87     2   122
# 3    2019   4  종로구    85     0   131
# 4    2019   5  종로구   112     1   158
# ..    ...  ..  ...   ...   ...   ...
# 295  2019   8  강동구   127     2   175
# 296  2019   9  강동구    98     2   137
# 297  2019  10  강동구   108     1   144
# 298  2019  11  강동구   146     0   199
# 299  2019  12  강동구   108     1   131
#
# [300 rows x 6 columns]

# %%
# 자치구별 별 합계
traffic_analysis = traffic_Seoul_2019.groupby('자치구명').sum()
# '년도', '월' column 삭제
traffic_analysis.drop(['년도', '월'], axis=1, inplace=True)
# 컬럼 순서 '발생건수', '부상자수', '사망자수' 순으로 변경
traffic_analysis = traffic_analysis[['발생건수', '부상자수', '사망자수']]
traffic_analysis.head()
# Out:
#       발생건수  부상자수  사망자수
# 자치구명
# 강남구   3722  5182    14
# 강동구   1414  1910    11
# 강북구   1277  1706     7
# 강서구   1829  2491    20
# 관악구   1363  1755    10

# %%
traffic_analysis2 = pd.pivot_table(traffic_Seoul_2019[['자치구명','발생건수', '부상자수', '사망자수']], index='자치구명', aggfunc=sum)
traffic_analysis2.head()
# Out:
#       발생건수  부상자수  사망자수
# 자치구명
# 강남구   3722  5182    14
# 강동구   1414  1910    11
# 강북구   1277  1706     7
# 강서구   1829  2491    20
# 관악구   1363  1755    10

# %%
seoul_limit = pd.read_csv('../Data/seoul.csv', encoding='euc-kr')
seoul_limit.columns = ['자치구명', 'lon', 'lat']
seoul_limit.head()
# Out:
#   자치구명       lon       lat
# 0  강남구  127.0475  37.51731
# 1  강동구  127.1238  37.53013
# 2  강북구  127.0255  37.63975
# 3  관악구  126.9515  37.47834
# 4  구로구  126.8875  37.49547

# %%
# merge
data_result = pd.merge(traffic_analysis, seoul_limit, on='자치구명')

# %%
data_result.head()
# Out:
#   자치구명  발생건수  부상자수  사망자수       lon       lat
# 0  강남구  3722  5182    14  127.0475  37.51731
# 1  강동구  1414  1910    11  127.1238  37.53013
# 2  강북구  1277  1706     7  127.0255  37.63975
# 3  강서구  1829  2491    20  126.8496  37.55094
# 4  관악구  1363  1755    10  126.9515  37.47834

# %%
data_result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25 entries, 0 to 24
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   자치구명    25 non-null     object
#  1   발생건수    25 non-null     int64
#  2   부상자수    25 non-null     int64
#  3   사망자수    25 non-null     int64
#  4   lon     25 non-null     float64
#  5   lat     25 non-null     float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 1.4+ KB

# %%
# int를 float로 변환
data_result[['발생건수', '부상자수', '사망자수']] = data_result[['발생건수', '부상자수', '사망자수']].astype(float)

# %%
data_result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25 entries, 0 to 24
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   자치구명    25 non-null     object
#  1   발생건수    25 non-null     float64
#  2   부상자수    25 non-null     float64
#  3   사망자수    25 non-null     float64
#  4   lon     25 non-null     float64
#  5   lat     25 non-null     float64
# dtypes: float64(5), object(1)
# memory usage: 1.4+ KB

# %%
import folium

# %%
# 지도 생성
map = folium.Map(location=[37.5502, 126.982], zoom_start=12)

# %%
# 지도 생성
map = folium.Map(location=[37.5502, 126.982], zoom_start=12)

# 마커 표시
for i in range(len(data_result)):
  html = '<h4>' + data_result.iloc[i]['자치구명'] + '</h4>'
  html += '<p>발생건수: ' + str(data_result.iloc[i]['발생건수']) + '</p>'
  html += '<p>부상자수: ' + str(data_result.iloc[i]['부상자수']) + '</p>'
  html += '<p>사망자수: ' + str(data_result.iloc[i]['사망자수']) + '</p>'
  popup = folium.Popup(html, min_width=100, max_width=100)
  map.add_child(folium.Marker(location=[data_result.iloc[i]['lat'], data_result.iloc[i]['lon']], popup=popup))
# 지도 출력
map.save('../Data/map.html')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_42c1981dc939f55dddaf38c8d7b53803 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_42c1981dc939f55dddaf38c8d7b53803&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_42c1981dc939f55dddaf38c8d7b53803 = L.map(
#                 &quot;map_42c1981dc939f55dddaf38c8d7b53803&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_63f97114ac558c4e91a162bbcf60b681 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_42c1981dc939f55dddaf38c8d7b53803);
#
#
#             var marker_a6e51ac15b15361886fd2495e0f9c419 = L.marker(
#                 [37.51731, 127.0475],
#                 {}
#             ).addTo(map_42c1981dc939f55dddaf38c8d7b53803);
#
#
#         var popup_068496842d8606cae4b953fe32d6ce63 = L.popup({&quot;maxWidth&quot;: 100, &quot;minWidth&quot;: 100});
#
#
#             var html_7a8660dff436b9fbe936885243392fde = $(`&lt;div id=&quot;html_7a8660dff436b9fbe936885243392fde&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h4&gt;강남구&lt;/h4&gt;&lt;p&gt;발생건수: 3722.0&lt;/p&gt;&lt;p&gt;부상자수: 5182.0&lt;/p&gt;&lt;p&gt;사망자수: 14.0&lt;/p&gt;&lt;/div&gt;`)[0];
#             popup_068496842d8606cae4b953fe32d6ce63.setContent(html_7a8660dff436b9fbe936885243392fde);
#
#
#         marker_a6e51ac15b15361886fd2495e0f9c419.bindPopup(popup_068496842d8606cae4b953fe32d6ce63)
#         ;
#
#
#
#
#             var marker_aa1f2014b98f7cbf90e7120eb81e3440 = L.marker(
#                 [37.53013, 127.1238],
#                 {}
#             ).addTo(map_42c1981dc939f55dddaf38c8d7b53803);
#
#
#         var popup_24ff4bcb1e436998c8de55251e5fc4ea = L.popup({&quot;maxWidth&quot;: 100, &quot;minWidth&quot;: 100});
#
#
#             var html_6c71c300b05c15151182d1c9a132f575 = $(`&lt;div id=&quot;html_6c71c300b05c15151182d1c9a132f575&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h4&gt;강동구&lt;/h4&gt;&lt;p&gt;발생건수: 1414.0&lt;/p&gt;&lt;p&gt;부상자수: 1910.0&lt;/p&gt;&lt;p&gt;사망자수: 11.0&lt;/p&gt;&lt;/div&gt;`)[0];
#             popup_24ff4bcb1e436998c8de55251e5fc4ea.setContent(html_6c71c300b05c15151182d1c9a132f575);
#
#
#         marker_aa1f2014b98f7cbf90e7120eb81e3440.bindPopup(popup_24ff4bcb1e436998c8de55251e5fc4ea)
#         ;
#
#
#
#
#             var marker_a98c59f90a06438afa92b970aacfc820 = L.marker(
#                 [37.63975, 127.0255],
#                 {}
#             ).addTo(map_42c1981dc939f55dddaf38c8d7b53803);
#
#
#         var popup_3b4e4043516ab37744fbab79330b4dbf = L.popup({&quot;maxWidth&quot;: 100, &quot;minWidth&quot;: 100});
#
#
#             var html_d90b89e44d3b9b9e98340856d5bb4237 = $(`&lt;div id=&quot;html_d90b89e44d3b9b9e98340856d5bb4237&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h4&gt;강북구&lt;/h4&gt;&lt;p&gt;발생건수: 1277.0&lt;/p&gt;&lt;p&gt;부상자수: 1706.0&lt;/p&gt;&lt;p&gt;사망자수: 7.0&lt;/p&gt;&lt;/div&gt;`)[0];
#             popup_3b4e4043516ab37744fbab79330b4dbf.setContent(html_d90b89e44d3b9b9e98340856d5bb4237);
#
#
#         marker_a98c59f90a06438afa92b970aacfc820.bindPopup(popup_3b4e4043516ab37744fbab79330b4dbf)
#         ;
#
#
#
#
#             var marker_3b29ae950392dad4707b135c24219ff7 = L.marker(
#                 [37.55094, 126.8496],
#                 {}
#             ).addTo(map_42c1981dc939f55dddaf38c8d7b53803);
#
#
#         var popup_7d974d3e16e718be9356d92bcad39659 = L.popup({&quot;maxWidth&quot;: 100, &quot;minWidth&quot;: 100});
#
#
#             var html_494a5a8c6aa93e97c9fc8a087ca8b04f = $(`&lt;div id=&quot;html_494a5a8c6aa93e97c9fc8a087ca8b04f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h4&gt;강서구&lt;/h4&gt;&lt;p&gt;발생건수: 1829.0&lt;/p&gt;&lt;p&gt;부상자수: 2491.0&lt;/p&gt;&lt;p&gt;사망자수: 20.0&lt;/p&gt;&lt;/div&gt;`)[0];
#             popup_7d974d3e16e718be9356d92bcad39659.setContent(html_494a5a8c6aa93e97c9fc8a087ca8b04f);
#
#
#         marker_3b29ae950392dad4707b135c24219ff7.bindPopup(popup_7d974d3e16e718be9356d92bcad39659)
#         ;
#
#
#
#
#             var marker_3d7c685cffc531608193cd0eb9d6d7da = L.marker(
#                 [37.47834, 126.9515],
#                 {}
#             ).addTo(map_42c1981dc939f55dddaf38c8d7b53803);
#
#
#         var popup_b9010336cbdb1e03a7159f52cdf507cf = L.popup({&quot;maxWidth&quot;: 100, &quot;minWidth&quot;: 100});
#
#
#             var html_ea834fd4903a71b346f1e340c3514dd0 = $(`&lt;div id=&quot;html_ea834fd4903a71b346f1e340c3514dd0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h4&gt;관악구&lt;/h4&gt;&lt;p&gt;발생건수: 1363.0&lt;/p&gt;&lt;p&gt;부상자수: 1755.0&lt;/p&gt;&lt;p&gt;사망자수: 10.0&lt;/p&gt;&lt;/div&gt;`)[0];
#             popup_b9010336cbdb1e03a7159f52cdf507cf.setContent(html_ea834fd4903a71b346f1e340c3514dd0);

# %%
data_result.head()
# Out:
#   자치구명    발생건수    부상자수  사망자수       lon       lat
# 0  강남구  3722.0  5182.0  14.0  127.0475  37.51731
# 1  강동구  1414.0  1910.0  11.0  127.1238  37.53013
# 2  강북구  1277.0  1706.0   7.0  127.0255  37.63975
# 3  강서구  1829.0  2491.0  20.0  126.8496  37.55094
# 4  관악구  1363.0  1755.0  10.0  126.9515  37.47834

# %%
# 자치구별 교통사고 발생건수를 표시하기
# 지도 생성
map = folium.Map(location=[37.5502, 126.982], zoom_start=12)
# 마커 표시
for i in range(len(data_result)):
  html = '<h4>' + data_result.iloc[i]['자치구명'] + '</h4>'
  html += '<p>발생건수: ' + str(data_result.iloc[i]['발생건수']) + '</p>'
  html += '<p>부상자수: ' + str(data_result.iloc[i]['부상자수']) + '</p>'
  html += '<p>사망자수: ' + str(data_result.iloc[i]['사망자수']) + '</p>'

  popup = folium.Popup(html, min_width=100, max_width=100)

  folium.Marker(location=[data_result.iloc[i]['lat'], data_result.iloc[i]['lon']], 
                popup=popup ).add_to(map)
  folium.CircleMarker(location=[data_result.iloc[i]['lat'], data_result.iloc[i]['lon']],
                      radius = data_result.iloc[i]['발생건수']/100, # 원의 반지름
                      color = "cornflowerblue", # 테두리 색
                      fill = True, # 색 채운다 , 안 써도 다른 옵션 주면 뜨더라,, 
                      fill_color = "skyblue", # 원 내부 색
                      fill_opacity = 0.3,# 원 내부 색의 투명도
   ).add_to(map)

# 지도 출력
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a1c1e2fa3e70dcdeedff203aae36c423 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a1c1e2fa3e70dcdeedff203aae36c423&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_a1c1e2fa3e70dcdeedff203aae36c423 = L.map(
#                 &quot;map_a1c1e2fa3e70dcdeedff203aae36c423&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f861c4afdbffe472043caddc17710d0d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a1c1e2fa3e70dcdeedff203aae36c423);
#
#
#             var marker_481dcb48a7c2ee2fc645e1ab8cdf5cf0 = L.marker(
#                 [37.51731, 127.0475],
#                 {}
#             ).addTo(map_a1c1e2fa3e70dcdeedff203aae36c423);
#
#
#         var popup_f17e484cb43ddb80df2df36e69f75ea6 = L.popup({&quot;maxWidth&quot;: 100, &quot;minWidth&quot;: 100});
#
#
#             var html_1d9f699b72d22855642182ad9267cb35 = $(`&lt;div id=&quot;html_1d9f699b72d22855642182ad9267cb35&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h4&gt;강남구&lt;/h4&gt;&lt;p&gt;발생건수: 3722.0&lt;/p&gt;&lt;p&gt;부상자수: 5182.0&lt;/p&gt;&lt;p&gt;사망자수: 14.0&lt;/p&gt;&lt;/div&gt;`)[0];
#             popup_f17e484cb43ddb80df2df36e69f75ea6.setContent(html_1d9f699b72d22855642182ad9267cb35);
#
#
#         marker_481dcb48a7c2ee2fc645e1ab8cdf5cf0.bindPopup(popup_f17e484cb43ddb80df2df36e69f75ea6)
#         ;
#
#
#
#
#             var circle_marker_4faa188f08708c43eb82e46c086ca45c = L.circleMarker(
#                 [37.51731, 127.0475],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;cornflowerblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;skyblue&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 37.22, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a1c1e2fa3e70dcdeedff203aae36c423);
#
#
#             var marker_a11c4d7bbe86b306080d6bab2df41dfb = L.marker(
#                 [37.53013, 127.1238],
#                 {}
#             ).addTo(map_a1c1e2fa3e70dcdeedff203aae36c423);
#
#
#         var popup_026a31def854b744695eced9f93b9fa6 = L.popup({&quot;maxWidth&quot;: 100, &quot;minWidth&quot;: 100});
#
#
#             var html_3d46e8d3d26e2554a246c9aa087ee3ec = $(`&lt;div id=&quot;html_3d46e8d3d26e2554a246c9aa087ee3ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h4&gt;강동구&lt;/h4&gt;&lt;p&gt;발생건수: 1414.0&lt;/p&gt;&lt;p&gt;부상자수: 1910.0&lt;/p&gt;&lt;p&gt;사망자수: 11.0&lt;/p&gt;&lt;/div&gt;`)[0];
#             popup_026a31def854b744695eced9f93b9fa6.setContent(html_3d46e8d3d26e2554a246c9aa087ee3ec);
#
#
#         marker_a11c4d7bbe86b306080d6bab2df41dfb.bindPopup(popup_026a31def854b744695eced9f93b9fa6)
#         ;
#
#
#
#
#             var circle_marker_c01c367fd7cf0183fc13ccdca136c695 = L.circleMarker(
#                 [37.53013, 127.1238],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;cornflowerblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;skyblue&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 14.14, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a1c1e2fa3e70dcdeedff203aae36c423);
#
#
#             var marker_aaa4c337e51a936ec94758caebbb68a4 = L.marker(
#                 [37.63975, 127.0255],
#                 {}
#             ).addTo(map_a1c1e2fa3e70dcdeedff203aae36c423);
#
#
#         var popup_279241055c8d2025b89fb655842a533d = L.popup({&quot;maxWidth&quot;: 100, &quot;minWidth&quot;: 100});
#
#
#             var html_044fd3364c4a9ad98fbab7adfe3816a5 = $(`&lt;div id=&quot;html_044fd3364c4a9ad98fbab7adfe3816a5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h4&gt;강북구&lt;/h4&gt;&lt;p&gt;발생건수: 1277.0&lt;/p&gt;&lt;p&gt;부상자수: 1706.0&lt;/p&gt;&lt;p&gt;사망자수: 7.0&lt;/p&gt;&lt;/div&gt;`)[0];
#             popup_279241055c8d2025b89fb655842a533d.setContent(html_044fd3364c4a9ad98fbab7adfe3816a5);
#
#
#         marker_aaa4c337e51a936ec94758caebbb68a4.bindPopup(popup_279241055c8d2025b89fb655842a533d)
#         ;
#
#
#
#
#             var circle_marker_d05847af40f91ff2fe55568e8dab8ac1 = L.circleMarker(
#                 [37.63975, 127.0255],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;cornflowerblue&quot;, &quot;dashArray&quot;: null, &quo

# %%
# 자치구별 교통사고 사망건수를 표시하기

# 지도 생성
map = folium.Map(location=[37.5502, 126.982], zoom_start=12)
# 마커 표시
for i in range(len(data_result)):
  html = '<h4>' + data_result.iloc[i]['자치구명'] + '</h4>'
  html += '<p>발생건수: ' + str(data_result.iloc[i]['발생건수']) + '</p>'
  html += '<p>부상자수: ' + str(data_result.iloc[i]['부상자수']) + '</p>'
  html += '<p>사망자수: ' + str(data_result.iloc[i]['사망자수']) + '</p>'

  popup = folium.Popup(html, min_width=100, max_width=100)

  folium.Marker(location=[data_result.iloc[i]['lat'], data_result.iloc[i]['lon']], 
                popup=popup ).add_to(map)
  folium.CircleMarker(location=[data_result.iloc[i]['lat'], data_result.iloc[i]['lon']],
                      radius = data_result.iloc[i]['사망자수']*3, # 원의 반지름
                      color = "red", # 테두리 색
                      fill = True, # 색 채운다 , 안 써도 다른 옵션 주면 뜨더라,, 
                      fill_color = "pink", # 원 내부 색
                      fill_opacity = 0.3,# 원 내부 색의 투명도
   ).add_to(map)

# 지도 출력
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2e9b2ca0762738979940d1f15fb0c81b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2e9b2ca0762738979940d1f15fb0c81b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_2e9b2ca0762738979940d1f15fb0c81b = L.map(
#                 &quot;map_2e9b2ca0762738979940d1f15fb0c81b&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_294bbc824aeefcbd3697edbbe05c7d45 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2e9b2ca0762738979940d1f15fb0c81b);
#
#
#             var marker_d9baf0fbdd9b4e129740ed636b61804c = L.marker(
#                 [37.51731, 127.0475],
#                 {}
#             ).addTo(map_2e9b2ca0762738979940d1f15fb0c81b);
#
#
#         var popup_ee6b807a559d55f06c78af6d151b5ef6 = L.popup({&quot;maxWidth&quot;: 100, &quot;minWidth&quot;: 100});
#
#
#             var html_dc25a1d492c1d4d9529a3589ca9f70ad = $(`&lt;div id=&quot;html_dc25a1d492c1d4d9529a3589ca9f70ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h4&gt;강남구&lt;/h4&gt;&lt;p&gt;발생건수: 3722.0&lt;/p&gt;&lt;p&gt;부상자수: 5182.0&lt;/p&gt;&lt;p&gt;사망자수: 14.0&lt;/p&gt;&lt;/div&gt;`)[0];
#             popup_ee6b807a559d55f06c78af6d151b5ef6.setContent(html_dc25a1d492c1d4d9529a3589ca9f70ad);
#
#
#         marker_d9baf0fbdd9b4e129740ed636b61804c.bindPopup(popup_ee6b807a559d55f06c78af6d151b5ef6)
#         ;
#
#
#
#
#             var circle_marker_b44e839eab787825e47c59e18f034072 = L.circleMarker(
#                 [37.51731, 127.0475],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;pink&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 42.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2e9b2ca0762738979940d1f15fb0c81b);
#
#
#             var marker_540e3291ed5019f7ba7c7522a77a5a3f = L.marker(
#                 [37.53013, 127.1238],
#                 {}
#             ).addTo(map_2e9b2ca0762738979940d1f15fb0c81b);
#
#
#         var popup_400d6a2b3f8ed74b809eaf61baa2b9ec = L.popup({&quot;maxWidth&quot;: 100, &quot;minWidth&quot;: 100});
#
#
#             var html_67bd96b9c32b60b9ba647683dd03bd05 = $(`&lt;div id=&quot;html_67bd96b9c32b60b9ba647683dd03bd05&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h4&gt;강동구&lt;/h4&gt;&lt;p&gt;발생건수: 1414.0&lt;/p&gt;&lt;p&gt;부상자수: 1910.0&lt;/p&gt;&lt;p&gt;사망자수: 11.0&lt;/p&gt;&lt;/div&gt;`)[0];
#             popup_400d6a2b3f8ed74b809eaf61baa2b9ec.setContent(html_67bd96b9c32b60b9ba647683dd03bd05);
#
#
#         marker_540e3291ed5019f7ba7c7522a77a5a3f.bindPopup(popup_400d6a2b3f8ed74b809eaf61baa2b9ec)
#         ;
#
#
#
#
#             var circle_marker_88dfa75c29095c77fe7561f53c7895bd = L.circleMarker(
#                 [37.53013, 127.1238],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;pink&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 33.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2e9b2ca0762738979940d1f15fb0c81b);
#
#
#             var marker_71f936eb94bedf1cd419dadd8375c9e7 = L.marker(
#                 [37.63975, 127.0255],
#                 {}
#             ).addTo(map_2e9b2ca0762738979940d1f15fb0c81b);
#
#
#         var popup_7a25a51ac2fdd927b05eadad44a2da79 = L.popup({&quot;maxWidth&quot;: 100, &quot;minWidth&quot;: 100});
#
#
#             var html_edc9bde880d1782a8dda07cd92519928 = $(`&lt;div id=&quot;html_edc9bde880d1782a8dda07cd92519928&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h4&gt;강북구&lt;/h4&gt;&lt;p&gt;발생건수: 1277.0&lt;/p&gt;&lt;p&gt;부상자수: 1706.0&lt;/p&gt;&lt;p&gt;사망자수: 7.0&lt;/p&gt;&lt;/div&gt;`)[0];
#             popup_7a25a51ac2fdd927b05eadad44a2da79.setContent(html_edc9bde880d1782a8dda07cd92519928);
#
#
#         marker_71f936eb94bedf1cd419dadd8375c9e7.bindPopup(popup_7a25a51ac2fdd927b05eadad44a2da79)
#         ;
#
#
#
#
#             var circle_marker_a5b4cf4fc059523632bbbfef84d0d525 = L.circleMarker(
#                 [37.63975, 127.0255],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot

# %%
# 자치구별 교통사고 사망건수를 최대 최소만 표시하기

# 지도 생성
map = folium.Map(location=[37.5502, 126.982], zoom_start=12)
# 마커 표시
for i in range(len(data_result)):
  html = '<h4>' + data_result.iloc[i]['자치구명'] + '</h4>'
  html += '<p>발생건수: ' + str(data_result.iloc[i]['발생건수']) + '</p>'
  html += '<p>부상자수: ' + str(data_result.iloc[i]['부상자수']) + '</p>'
  html += '<p>사망자수: ' + str(data_result.iloc[i]['사망자수']) + '</p>'

  popup = folium.Popup(html, min_width=100, max_width=100)

  folium.Marker(location=[data_result.iloc[i]['lat'], data_result.iloc[i]['lon']], 
                popup=popup ).add_to(map)

folium.CircleMarker(location=[data_result.iloc['lat'].max, data_result.iloc['lon']],
                    radius = data_result.iloc[i]['사망자수']*3, # 원의 반지름
                    color = "red", # 테두리 색
                    fill = True, # 색 채운다 , 안 써도 다른 옵션 주면 뜨더라,, 
                    fill_color = "pink", # 원 내부 색
                    fill_opacity = 0.3,# 원 내부 색의 투명도
).add_to(map)
# 지도 출력
map
